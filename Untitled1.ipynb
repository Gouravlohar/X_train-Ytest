# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

path="/content/drive/MyDrive/files/zomato.csv"
dataset=pd.read_csv(path)
dataset.head(10)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Unnamed: 0                                             name online_order  \
# 0           0                                            Jalsa          Yes
# 1           1                                   Spice Elephant          Yes
# 2           2                                  San Churro Cafe          Yes
# 3           3                            Addhuri Udupi Bhojana           No
# 4           4                                    Grand Village           No
# 5           5                                  Timepass Dinner          Yes
# 6           6  Rosewood International Hotel - Bar & Restaurant           No
# 7           7                                           Onesta          Yes
# 8           8                                   Penthouse Cafe          Yes
# 9          10                                        Smacznego          Yes
#
# ...

# %%
online_order={'Yes':1,'No':0}
book_table={'Yes':1,'No':0}
dataset.online_order = [online_order[item] for item in dataset.online_order]
dataset.book_table = [book_table[item] for item in dataset.book_table]

# %%
dataset.head(10)
# Out:
#    Unnamed: 0                                             name  online_order  \
# 0           0                                            Jalsa             1
# 1           1                                   Spice Elephant             1
# 2           2                                  San Churro Cafe             1
# 3           3                            Addhuri Udupi Bhojana             0
# 4           4                                    Grand Village             0
# 5           5                                  Timepass Dinner             1
# 6           6  Rosewood International Hotel - Bar & Restaurant             0
# 7           7                                           Onesta             1
# 8           8                                   Penthouse Cafe             1
# 9          10                                        Smacznego             1
#
#    book_table  rating  votes      location            rest_type  \
# ...

# %%
x=dataset.iloc[:,0:-1].values
y=dataset.iloc[:,-1].values
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=0)

# %%
x_train
# Out:
# array([[19511, 'Cup Shup', 1, ...,
#         'Sandwiches, Coffee, Burgers, Chicken Wrap, Rolls, Ginger Tea, Chicken Sandwich',
#         'Cafe, Continental, Fast Food', '500'],
#        [33608, 'Entropy Cafe', 1, ...,
#         'Nachos, Biryani, Chaat, Pancakes, Pizza, Pasta, Burgers',
#         'Cafe, Chinese, Pizza, North Indian, Burger', '600'],
#        [55608, 'The Fat Chef', 1, ...,
#         'Caesar Salad, Khao Suey, Veggie Pizza, Beef Steak, Pasta, Peri Peri Chicken Pizza, Mousse',
#         'Japanese, Italian, American, Asian, North Indian, Steak',
#         '1,400'],
#        ...,
#        [14964, '46 Ounces Brewgarden', 0, ...,
#         'Pizza, Craft Beer, French Fries',
#         'Bar Food, Finger Food, Pizza', '1,600'],
#        [16931, 'Firangi Bake', 1, ..., nan, 'Mexican, Italian', '600'],
#        [3916, 'RRoyal Rajasthan', 1, ...,
#         'Dal Bati, Gatte Ki Subzi, Churma, Rasmalai, Dahi Vada, Khichda, Chaach',
# ...
